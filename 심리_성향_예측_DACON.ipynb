# %% [markdown]
# <a href="https://colab.research.google.com/github/parkyw2/DACON/blob/main/%EC%8B%AC%EB%A6%AC_%EC%84%B1%ED%96%A5_%EC%98%88%EC%B8%A1_DACON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/My\ Drive/데이콘/심리성향예측
# Out:
# /content/drive/My Drive/데이콘/심리성향예측

# %%
import pandas as pd
train = pd.read_csv('train.csv')
test = pd.read_csv('test_x.csv')
submission = pd.read_csv('sample_submission.csv')

# %%
print(train.shape)
print(test.shape)
print(submission.shape)
# Out:
# (45532, 78)
# (11383, 77)
# (11383, 2)

# %%
# !pip install pycaret[full]

# %%
#모듈 불러오기
import pandas as pd
import numpy as np
import matplotlib as mpl
from google.colab import files
from xgboost import XGBRegressor
# !pip install catboost
from catboost import CatBoostRegressor

# %%
from pycaret.classification import *

# %%
# 'voted' 컬럼이 예측 대상이므로 target 인자에 명시
# 'voted' column is the target variable
clf = setup(data = train, target = 'voted')
# Out:
#                                Description             Value
# 0                               session_id              3407
# 1                                   Target             voted
# 2                              Target Type            Binary
# 3                            Label Encoded              None
# 4                            Original Data       (45532, 78)
# 5                           Missing Values             False
# 6                         Numeric Features                42
# 7                     Categorical Features                35
# 8                         Ordinal Features             False
# 9                High Cardinality Features             False
# 10                 High Cardinality Method              None
# 11                   Transformed Train Set      (31872, 183)
# 12                    Transformed Test Set      (13660, 183)
# 13                      Shuffle Train-Test              True
# ...

# %%
best_3 = compare_models(sort = 'AUC', n_select = 3)
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# catboost              CatBoost Classifier    0.6949  0.7661  0.7411  0.6401
# gbc          Gradient Boosting Classifier    0.6941  0.7646  0.7687  0.6328
# lightgbm  Light Gradient Boosting Machine    0.6933  0.7638  0.7567  0.6345
# lda          Linear Discriminant Analysis    0.6912  0.7618  0.7280  0.6387
# et                 Extra Trees Classifier    0.6926  0.7597  0.7544  0.6343
# ada                  Ada Boost Classifier    0.6908  0.7567  0.7350  0.6366
# rf               Random Forest Classifier    0.6853  0.7545  0.7521  0.6261
# xgboost         Extreme Gradient Boosting    0.6744  0.7467  0.6893  0.6270
# dt               Decision Tree Classifier    0.6087  0.6051  0.5687  0.5665
# lr                    Logistic Regression    0.5526  0.5922  0.0300  0.5152
# nb                            Naive Bayes    0.4547  0.5312  0.9824  0.4522
# ...

# %%
blended = blend_models(estimator_list = best_3, fold = 5, method = 'soft')
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.6988  0.7674  0.7728  0.6374  0.6986  0.4031  0.4106
# 1       0.6891  0.7644  0.7652  0.6278  0.6897  0.3842  0.3918
# 2       0.6916  0.7647  0.7436  0.6354  0.6852  0.3865  0.3911
# 3       0.6964  0.7665  0.7703  0.6351  0.6962  0.3984  0.4058
# 4       0.7022  0.7716  0.7582  0.6448  0.6969  0.4080  0.4132
# Mean    0.6956  0.7669  0.7620  0.6361  0.6933  0.3961  0.4025
# SD      0.0048  0.0026  0.0105  0.0054  0.0050  0.0093  0.0093

# %%
pred_holdout = predict_model(blended)
# Out:
#                Model  Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0  Voting Classifier    0.6988  0.7663   0.764  0.6435  0.6986  0.4019  0.4078
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1053/711029253.py in <module>
# ----> 1 pred_holdout = predict_model(blended)
#
# /usr/local/lib/python3.7/dist-packages/pycaret/classification.py in predict_model(estimator, data, probability_threshold, encoded_labels, raw_score, drift_report, round, verbose)
#    2032         round=round,
#    2033         verbose=verbose,
# -> 2034         ml_usecase=MLUsecase.CLASSIFICATION,
#    2035     )
#    2036
#
# /usr/local/lib/python3.7/dist-packages/pycaret/internal/tabular.py in predict_model(estimator, data, probability_threshold, encoded_labels, drift_report, raw_score, round, verbose, ml_usecase, display)
#    8868         pred = pred.astype(int)
# ...

# %%
final_model = finalize_model(blended)
